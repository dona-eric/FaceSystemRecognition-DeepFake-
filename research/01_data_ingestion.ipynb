# %% [markdown]
# ### DATA INGESTION

# %%
import os, sys
import zipfile

# %%
# !pwd
# Out:
# /home/donerick/FaceSystemRecognition-DeepFake-/research

# %%
# %ls
# Out:
# 01_data_ingestion.ipynb  FaceImages.zip  trials.ipynb

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/home/donerick/FaceSystemRecognition-DeepFake-'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    source_url: str
    local_data_file: Path
    unzip_dir: Path
    root_dir: Path

# %%
import sys
from pathlib import Path
from src.Face_Recognition_System.constants import *
from src.Face_Recognition_System.utils.common import create_directories, read_yml

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath: Path = CONFIG_FILE_PATH,
        params_filepath: Path = PARAMS_FILE_PATH,
    ):
        self.config = read_yml(config_filepath)
        self.params = read_yml(params_filepath)

        create_directories([Path(self.config.artifacts_root)])


    def data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([Path(config.unzip_dir)])

        data_ingestion_config = DataIngestionConfig(
            source_url=config.source_url,
            local_data_file=Path(config.local_data_file),
            unzip_dir=Path(config.unzip_dir),
            root_dir=Path(config.root_dir),
        )

        return data_ingestion_config

# %%
# Function to unzip the data to 'artifacts' directory
from Face_Recognition_System import logger
from pathlib import Path
import zipfile


def unzip_file(zip_file_path: Path, unzip_dir: Path) -> None:
    """Unzips a zip file to a specified directory.

    Args:
        zip_file_path (Path): The path to the zip file.
        unzip_dir (Path): The directory where the contents will be extracted.
    """
    unzip_dir.mkdir(exist_ok=True)
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(unzip_dir)


    logger.info(f"The dataset HumanFace is unzip path:{unzip_dir}")

zip_file_path = Path("/home/donerick/FaceSystemRecognition-DeepFake-/research/FaceImages.zip")
artifacts_dir = Path('artifacts')
unzip_file(zip_file_path, artifacts_dir)
# Out:
# [2026-01-22 14:29:47,302: INFO: 2626045734: The dataset HumanFace is unzip path:artifacts]
